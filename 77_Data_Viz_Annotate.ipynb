# %% [markdown]
# <a href="https://colab.research.google.com/github/JhonnyLimachi/Sigmoidal/blob/main/77_Data_Viz_Annotate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Visualizações de Dados com Python**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---

# %% [markdown]
# # Inserindo Anotações em um Plot

# %%
# importar as bibliotecas necessárias
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# %%
# configurar a visualização
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg' # melhorar a resolução das imagens, figura vetorial

# %%
# dados a serem plotados
labels = ['Fortemente\nContra', 'Contra', 'Neutro', 'Favoravel', 'Fortemente\nFavoravel']
antes = [22, 37, 17, 15, 9]
depois = [12, 10, 16, 33, 39]

# %%
# criar uma figura para grafico de barras
fig, ax = plt.subplots(figsize=(8, 4))

# plotar antes e depois saparadamente
#ax.bar(labels, antes)
#ax.bar(labels, depois)

x = np.arange(len(labels)) # espaçando as barras
width_bar = 0.35

# grouped bar with labels
rects1 = ax.bar(x - width_bar/2, antes, width_bar, label='Antes')
rects2 = ax.bar(x + width_bar/2, depois, width_bar, label='Depois')

# labels do eixo
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylabel('Porcentagem')

# título
ax.set_title('Apoio popular à Operação XYZ')

# legenda
ax.legend()

# plotar gráfico
fig.tight_layout() # ajusta o tamanho da figura
plt.show()

# %%
# configurando parâmetros das fontes
plt.rcParams['font.family'] = 'sans-serif'

# definindo cores do gráfico
CINZA1, CINZA2, CINZA3= "#CFCDCE", "#A2A1A3", "#787878"
AZUL1, AZUL2 = "#8db7eb", "#253760"

# %%
# ajustes para construir o gráfico
x = np.arange(len(labels))
width_bar = 0.35

# definir cores por plot
cores_antes = [CINZA1, CINZA1, CINZA1, CINZA3, CINZA3]
cores_depois = [AZUL1, AZUL1, AZUL1, AZUL2, AZUL2]

# %%
# criar uma figura para grafico de barras
fig, ax = plt.subplots(figsize=(8, 4))

# plotar antes e depois saparadamente
rects1 = ax.bar(x - width_bar/2, antes, width_bar, label='Antes', color=cores_antes)
rects2 = ax.bar(x + width_bar/2, depois, width_bar, label='Depois', color=cores_depois)

# labels do eixo
x = np.arange(len(labels))
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylabel('Porcentagem')

# # remover grids e eixos
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# # remover eixo y
plt.gca().axes.get_yaxis().set_visible(False)

# # remover xticks do eixo x
plt.tick_params(
    axis='both',
    which='both',
    bottom=False,
    top=False,
    labelbottom=True)

#criar função para dar labels automaticamente
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(
                    '{}%'.format(height),
                    xy=(rect.get_x() + rect.get_width()/2,  height),
                    xytext=(0, -20),  # offset
                    textcoords="offset points",
                    ha='center',
                    va='bottom',
                    fontsize=10,
                    color="red",
                    )

# plotar labels dentro das barras
autolabel(rects1)
autolabel(rects2)

# plotar título
plt.text(-0.35, 52, 'Apoio popular à Operação XYZ',
         fontsize=16,
         color=CINZA3,
         weight='bold')

# plotar subtitulo
plt.text(-0.35, 49,
         "Efetividade da campanha\n"
         "junto à população ribeirinha",
         verticalalignment="top",
         fontsize=12,
         color=CINZA2)

# plotar anotações do resultado da campanha
plt.text(4.5, 39,
         "$\\bf{RESULTADO}$\n"
         "de uma campanha\n"
         "de marketing junto\n"
         "à população, onde o\n"
         "apoio chegou a 39%."
         ,
         verticalalignment="top",
         fontsize=12,
         color=AZUL2)

# plotar o gráfico
fig.tight_layout()
plt.show()

# %% [markdown]
# ## **Anotando e Customizando Gráficos com Data Storytelling**
#
# Links úteis:
#
# [Documentação Oficial do Matplotlib](https://matplotlib.org/stable/gallery/text_labels_and_annotations/annotation_demo.html)
#
# [Annotations - Matplotlib](https://matplotlib.org/stable/users/explain/text/annotations.html)
#
# [Anotando em Plots - Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/04.09-text-and-annotation.html)
#
# Master plt.annotate() - [Towards Data Science ](https://towardsdatascience.com/finally-learn-to-annotate-place-text-in-any-part-of-the-plot-d9bcc93c153f)
#
# Matplotlib.pyplot.annotate() - [Geeks for Geeks](https://www.geeksforgeeks.org/matplotlib-pyplot-annotate-in-python/)
